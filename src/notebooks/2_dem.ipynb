# %%
import rasterio
import matplotlib.pyplot as plt

dem_path="../../data/dem/merged_terrain.tif"

# %%
f=rasterio.open(dem_path)

# %%
dem=f.read()[0]

# %%
plt.imshow(dem, cmap="gray")

# %%
f.crs
# Out:
# CRS.from_wkt('PROJCS["ETRS89 Lambert Azimutal Equal Area",GEOGCS["ETRS89 geographiques (dms)",DATUM["European_Terrestrial_Reference_System_1989",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6258"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Lambert_Azimuthal_Equal_Area"],PARAMETER["latitude_of_center",52],PARAMETER["longitude_of_center",10],PARAMETER["false_easting",4321000],PARAMETER["false_northing",3210000],UNIT["metre",1],AXIS["Easting",EAST],AXIS["Northing",NORTH]]')

# %%
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 rasterio.crs.epsg_treats_as_latlong(f)
#
# File rasterio/crs.pyx:1070, in rasterio.crs.epsg_treats_as_latlong()
#
# File rasterio/crs.pyx:783, in rasterio.crs.CRS.from_user_input()
#
# CRSError: CRS is invalid: <open DatasetReader name='../../data/dem/merged_terrain.tif' mode='r'>
